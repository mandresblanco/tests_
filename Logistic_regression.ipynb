# %% [markdown]
# <a href="https://colab.research.google.com/github/mandresblanco/tests_/blob/main/Logistic_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from mpl_toolkits.mplot3d import Axes3D  
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# $$
# L = \hat{y}y+(1-\hat{y})(1-y)
# $$

# %%
#yp es probabilidad
def likehood(y, yp):
  return yp*y + (1-yp)*(1-y)

# %%
#crea el espacio en 3d
fig = plt.figure()
ax = fig.gca(projection = '3d')

Y= np.arange(0, 1, 0.01)
YP= np.arange(0, 1, 0.01)
Y, YP = np.meshgrid(Y,YP)
Z = likehood(Y, YP) #CREA eje Z 

surf = ax.plot_surface(Y, YP, Z, cmap = cm.coolwarm)
fig.colorbar(surf, shrink=0.8, aspect=5)
plt.show()

# %%
from sklearn.datasets import load_iris
from sklearn.linear_model import LogisticRegression

# %%
atrib_names = ['sepal length', 'sepal width', 'petal length', 'petal width']
X, y = load_iris(return_X_y=True)

# %%
clf = LogisticRegression(random_state=10, solver='liblinear').fit(X[:100], y[:100])

# %%
#slos coeficientes (b0, b1...bn) que maximixan la probabilidad
clf.coef_
# Out:
# [[-0.40247392 -1.46382925  2.23785648  1.00009294]]
